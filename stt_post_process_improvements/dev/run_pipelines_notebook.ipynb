# %%
import whisper
import os
from jiwer import wer
import pandas as pd
from typing import Literal 
import numpy as np
from unidecode import unidecode
from abc import ABC, abstractmethod
from typing import List, Optional, Dict, Any

# Assuming OpenAI client library is already installed
from openai import OpenAI

import sys
sys.modules.pop('agents_pipeline', None)
from utils import normalize_text
from agents_pipeline import BasePipeline, GenerateWhisperPromptPipeline, GenerateNamesPipeline, GenerateTopicPipeline, FixTranscriptByLLMPipeline

import warnings
warnings.filterwarnings(
    "ignore",
    message="FP16 is not supported on CPU; using FP32 instead",
    category=UserWarning,
)

# %%
#API_KEY
API_KEY = "Put your OpenAI API key here"

# Parameters:
GPT_MODEL_NAME = "gpt-4o"

# %%
full_prompt_pipeline = GenerateWhisperPromptPipeline(api_key=API_KEY)
names_pipeline = GenerateNamesPipeline(api_key=API_KEY)

# %%
whisper_model = whisper.load_model("medium.en", "cpu")
# Out:
# /Users/yonathan_ron/documents/miniconda3/miniconda3/envs/stt_project/lib/python3.11/site-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)

# %%
transcript = """
                They got a two-on-one facing Gordon and Caruso lays it in man He's been so valuable off the bench this season for the Thunder inside home grip And he barely draws iron Wallace with a hustle and the stick back
                Gilders Alexander with a rebound plenty of time. He can walk it across those tween draws the foul He goes to the right hand and he gets fouled by Peyton watch. It just runs right into the old SGA flock
                25 points tied for the fewest combined total in any first quarter in post-season history. Runner to begin the second quarter is up and in for the Thunder. They have a double-digit lead 19-8. And they turn them over.
                With great hands by Kason Wallace. What a pest. Hardinstein catching a body. Another pick from Gore. Murray through the window to A.G. 10-footer. Yes! Finally, Denver's third bucket of the basketball game.
            """
is_generated, initial_prompt = await names_pipeline.process(transcript)
print(f"is_generated: {is_generated}, Initial Prompt for Whisper: {initial_prompt}")
# Out:
# is_generated: True, Initial Prompt for Whisper: Aaron Gordon, Alex Caruso, Chet Holmgren, Wallace, Shai Gilgeous-Alexander, Payton Watson, Kason Wallace, Isaiah Hartenstein, Jamal Murray

# %%
# Utils
def load_csv(file_path: str, header_col = 1) -> pd.DataFrame:
    """Load a CSV file into a DataFrame."""
    return pd.read_csv(file_path, header=header_col)

# %%
async def run_flow(df: pd.DataFrame, path_prefix: str, output_file: str = "output", Pipelines: List[BasePipeline] = None,
                   print_results: bool = False, save_results: bool = False) -> None:

    for index in range(df.shape[0]):
        ground_truth = df.iloc[index]["transcript"]
        file_path = os.path.join(path_prefix, df.iloc[index]["segment_filename"])
        transcription_raw = whisper.transcribe(whisper_model, file_path)["text"]
        transcription_raw_norm = normalize_text(transcription_raw).strip()
        ground_truth_norm = normalize_text(ground_truth).strip()
        wer_before = wer(truth=ground_truth_norm, hypothesis=transcription_raw_norm)
        print(f"start {index} from {df.shape[0]}")
        if save_results:
            df.at[index, f"stt_raw_norm"]  = transcription_raw_norm
            df.at[index, f"stt_raw_wer"]  = wer_before

        for pipeline in Pipelines: 
            runs = []          
            for run_idx in range(pipeline.get_num_iterations_allowed()):
                try:
                    is_generated_initial_prompt, pipeline_response = await pipeline.process(transcription_raw)
                    output_generated = pipeline_response
                    if is_generated_initial_prompt:
                        if pipeline_response is None or len(pipeline_response) == 0: 
                            print(f"Pipeline {pipeline.get_pipeline_name()} returned an empty response.")
                            output_generated = transcription_raw_norm
                        else:     
                            try:
                                initial_prompt = unidecode(pipeline_response).strip()
                            except Exception as e:
                                print(f"Error decoding pipeline response: {e}")
                                initial_prompt = pipeline_response
                            transcription_with_prompt = whisper.transcribe(whisper_model, file_path, initial_prompt=initial_prompt)["text"]
                            output_generated = transcription_with_prompt

                            # Check if the transcription with prompt is significantly different from the raw transcription, which mean it is corrupted.
                            if abs(len(transcription_raw_norm) - len(transcription_with_prompt)) > len(transcription_raw_norm) * 0.2:
                                print(f"{pipeline.get_pipeline_name()} is corrupted")
                                flow_output_norm = transcription_raw_norm
                                if save_results:
                                    df.at[index, f"{pipeline.get_pipeline_name()}_is_corrupted"] = True
                    else:
                        initial_prompt = None


                    flow_output_norm = normalize_text(output_generated).strip()
                    print(f"flow_output_norm: {pipeline_response}")
                    
                    wer_after = wer(truth=ground_truth_norm, hypothesis=flow_output_norm)

                        
                    runs.append({
                        "id": run_idx,
                        "wer": wer_after,
                        "flow_output_norm": flow_output_norm,
                        "initial_prompt": initial_prompt
                    })

                    break

                except Exception as e:
                    print(f"Error processing index {index} with pipeline {pipeline.get_pipeline_name()}: {e}")
                    continue

            if len(runs) == 0:
                print(f"No runs were successful for index {index} with pipeline {pipeline.get_pipeline_name()}.")
                continue

            key_fn = (lambda x: x["wer"])
            selected = min(runs, key=key_fn)
                
            if print_results:
                print(f"index: {index}, Pipeline: {pipeline.get_pipeline_name()}")
                print(f"Target:------------------->{ground_truth_norm}")
                print(f"STT raw:------------------>{transcription_raw_norm}")
                print(f"After Flow:--------------->{selected['flow_output_norm']}")

                result = "*Improved*" if selected['wer'] < wer_before else "*Not Improved*" if  selected['wer'] > wer_before else "*Same Result*"
                print(f"{result}, WER before LLM correction: {wer_before:.4f}, WER after LLM correction: {selected['wer']:.4f}")
                print()


            if save_results:
                if is_generated_initial_prompt and initial_prompt is not None:
                    df.at[index, f"{pipeline.get_pipeline_name()}_initial_prompt"] = selected["initial_prompt"]
                df.at[index, f"{pipeline.get_pipeline_name()}_norm"] = selected["flow_output_norm"]
                df.at[index, f"{pipeline.get_pipeline_name()}_wer"] = selected["wer"]


    
    if save_results:
        df.to_csv(f"{output_file}.csv", index=False)
        print(f"Results saved to {output_file}")

# %%
num_iterations = 3 # Number of iterations allowed until first success

Pipelines: List[BasePipeline] = [
    FixTranscriptByLLMPipeline(api_key=API_KEY, pipline_name="FixTranscriptByLLMPipeline", num_iterations_allowed=num_iterations, verbose=False),
    GenerateWhisperPromptPipeline(api_key=API_KEY, pipline_name="GenerateWhisperPromptPipeline", num_iterations_allowed=num_iterations, verbose=False),
    GenerateNamesPipeline(api_key=API_KEY, pipline_name="GenerateNamesPipeline", num_iterations_allowed=num_iterations, verbose=False),
    GenerateTopicPipeline(api_key=API_KEY, pipline_name="GenerateTopicPipeline", num_iterations_allowed=num_iterations, verbose=False),
]   

# Run the flow with the defined pipelines
file_name = "fs8ryPzUgW0"
date_str = "1.8.25"
csv_file_path = f"../notebooks/downloads/segments_metadata_{file_name}.csv"
df = load_csv(csv_file_path)
path_prefix=f"../notebooks/downloads/segments/"
await run_flow(df, path_prefix, f"full_report_{file_name}_{date_str}", Pipelines, print_results=True, save_results=True)
# Out:
# start 0 from 24
# flow_output_norm: Three games of playoff action coming at you with a lot of defense. The boost is the NBA.com Top 10. But first, at number 10, Franz Wagner.
# index: 0, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# STT raw:------------------>three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# After Flow:--------------->three games of playoff action coming at you with a lot of defense the boost is the nba com top ten but first at number ten franz wagner
# *Not Improved*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0357
#
# Best Names: ['Franz Wagner']
# sentence build: Franz Wagner is impressive on the court, showing remarkable skill in basketball.
# flow_output_norm: Franz Wagner is impressive on the court, showing remarkable skill in basketball.
# index: 0, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# STT raw:------------------>three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# After Flow:--------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Franz Wagner]
# index: 0, Pipeline: GenerateNamesPipeline
# Target:------------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# STT raw:------------------>three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# After Flow:--------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: NBA Playoffs Highlights
# index: 0, Pipeline: GenerateTopicPipeline
# Target:------------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# STT raw:------------------>three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# After Flow:--------------->three games of playoff action coming at you with a lot of defense the boot is the nba com top ten but first at number ten franz wagner
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 1 from 24
# flow_output_norm: The tween, the tween, the spin, the win
# Left-handed layup off the glass
# Putting Porzingis in the blender
# To get us going at number 9
# index: 1, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->between between the spin the win left handed layup off the glass put in porzingis in the blender to get us going at number nine
# STT raw:------------------>the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# After Flow:--------------->the tween the tween the spin the win left handed layup off the glass putting porzingis in the blender to get us going at number nine
# *Improved*, WER before LLM correction: 0.2800, WER after LLM correction: 0.2400
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 1, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->between between the spin the win left handed layup off the glass put in porzingis in the blender to get us going at number nine
# STT raw:------------------>the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# After Flow:--------------->the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# *Same Result*, WER before LLM correction: 0.2800, WER after LLM correction: 0.2800
#
# flow_output_norm: [Kristaps Porzingis]
# index: 1, Pipeline: GenerateNamesPipeline
# Target:------------------->between between the spin the win left handed layup off the glass put in porzingis in the blender to get us going at number nine
# STT raw:------------------>the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# After Flow:--------------->the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# *Same Result*, WER before LLM correction: 0.2800, WER after LLM correction: 0.2800
#
# flow_output_norm: Basketball highlights
# index: 1, Pipeline: GenerateTopicPipeline
# Target:------------------->between between the spin the win left handed layup off the glass put in porzingis in the blender to get us going at number nine
# STT raw:------------------>the tween the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# After Flow:--------------->between the tween the spin the wind left handed layup off the glass putting porzingis in the blender to get us going at number nine
# *Improved*, WER before LLM correction: 0.2800, WER after LLM correction: 0.2000
#
# start 2 from 24
# flow_output_norm: Top of the key, Tyrese, with the alley-oop and the tomahawk jam! Hezzy freezes Portis and drives down the lane.
# index: 2, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->top of the key tyrese what the hellly burton tomahawk champ hezzy freezes portis and drives down the lane
# STT raw:------------------>top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# After Flow:--------------->top of the key tyrese with the alley oop and the tomahawk jam hezzy freezes portis and drives down the lane
# *Not Improved*, WER before LLM correction: 0.2632, WER after LLM correction: 0.3158
#
# Best Names: ['Tyrese Haliburton']
# sentence build: Tyrese Haliburton was the standout player on the court, showcasing his skills with every move.
# flow_output_norm: Tyrese Haliburton was the standout player on the court, showcasing his skills with every move.
# index: 2, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->top of the key tyrese what the hellly burton tomahawk champ hezzy freezes portis and drives down the lane
# STT raw:------------------>top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# After Flow:--------------->top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# *Same Result*, WER before LLM correction: 0.2632, WER after LLM correction: 0.2632
#
# flow_output_norm: [Tyrese Haliburton, Bobby Portis]
# index: 2, Pipeline: GenerateNamesPipeline
# Target:------------------->top of the key tyrese what the hellly burton tomahawk champ hezzy freezes portis and drives down the lane
# STT raw:------------------>top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# After Flow:--------------->top of the key tyrese what the hell it burton tomahawk jam hezzy freezes portis and drives down the lane
# *Improved*, WER before LLM correction: 0.2632, WER after LLM correction: 0.1579
#
# flow_output_norm: Basketball play-by-play
# index: 2, Pipeline: GenerateTopicPipeline
# Target:------------------->top of the key tyrese what the hellly burton tomahawk champ hezzy freezes portis and drives down the lane
# STT raw:------------------>top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# After Flow:--------------->top of the key tyrese what the hell it burnt in tomahawk jam hezzy freezes portis and drives down the lane
# *Same Result*, WER before LLM correction: 0.2632, WER after LLM correction: 0.2632
#
# start 3 from 24
# flow_output_norm: with authority. Number eight off the inbound, Anthony Black, the steal, the layup.
# index: 3, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->with authority number eight off the inbound anthony black the steal the layup
# STT raw:------------------>with authority number eight off the inbound anthony black to steal the layup
# After Flow:--------------->with authority number eight off the inbound anthony black the steal the layup
# *Improved*, WER before LLM correction: 0.0769, WER after LLM correction: 0.0000
#
# Best Names: ['Anthony Black']
# sentence build: "Exploring the game, Anthony Black showcases his skills on the court."
# flow_output_norm: "Exploring the game, Anthony Black showcases his skills on the court."
# index: 3, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->with authority number eight off the inbound anthony black the steal the layup
# STT raw:------------------>with authority number eight off the inbound anthony black to steal the layup
# After Flow:--------------->with authority number eight off the inbound anthony black to steal the layup
# *Same Result*, WER before LLM correction: 0.0769, WER after LLM correction: 0.0769
#
# flow_output_norm: [Anthony Black]
# index: 3, Pipeline: GenerateNamesPipeline
# Target:------------------->with authority number eight off the inbound anthony black the steal the layup
# STT raw:------------------>with authority number eight off the inbound anthony black to steal the layup
# After Flow:--------------->with authority number eight off the inbound anthony black to steal the layup
# *Same Result*, WER before LLM correction: 0.0769, WER after LLM correction: 0.0769
#
# flow_output_norm: Basketball Game Play
# index: 3, Pipeline: GenerateTopicPipeline
# Target:------------------->with authority number eight off the inbound anthony black the steal the layup
# STT raw:------------------>with authority number eight off the inbound anthony black to steal the layup
# After Flow:--------------->with authority number eight off the inbound anthony black to steal the layup
# *Same Result*, WER before LLM correction: 0.0769, WER after LLM correction: 0.0769
#
# start 4 from 24
# flow_output_norm: in the paint anticipates the pass. Whole lot of defense converted it to, oh, number seven, Derrick White finds Tatum. Wing jumper misses.
# index: 4, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derrek white finds tatum wing jumper misses
# STT raw:------------------>in the paint anticipates the pass whole lot of defense converted it to oh number seven derek white finds tatum wing jumper misses
# After Flow:--------------->in the paint anticipates the pass whole lot of defense converted it to oh number seven derrick white finds tatum wing jumper misses
# *Same Result*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0870
#
# Best Names: ['Derrick White', 'Jayson Tatum']
# sentence build: Derrick White and Jayson Tatum led the charge on the court, showcasing their skills in spectacular fashion.
# flow_output_norm: Derrick White and Jayson Tatum led the charge on the court, showcasing their skills in spectacular fashion.
# index: 4, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derrek white finds tatum wing jumper misses
# STT raw:------------------>in the paint anticipates the pass whole lot of defense converted it to oh number seven derek white finds tatum wing jumper misses
# After Flow:--------------->and the paint anticipates the pass whole lot of defense converted it to zero number seven derrick white finds tatum wayne jumper misses
# *Not Improved*, WER before LLM correction: 0.0870, WER after LLM correction: 0.1304
#
# flow_output_norm: [Derrick White, Jayson Tatum]
# index: 4, Pipeline: GenerateNamesPipeline
# Target:------------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derrek white finds tatum wing jumper misses
# STT raw:------------------>in the paint anticipates the pass whole lot of defense converted it to oh number seven derek white finds tatum wing jumper misses
# After Flow:--------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derrick white finds tatum wing jumper misses
# *Improved*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0435
#
# flow_output_norm: Basketball Game Commentary
# index: 4, Pipeline: GenerateTopicPipeline
# Target:------------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derrek white finds tatum wing jumper misses
# STT raw:------------------>in the paint anticipates the pass whole lot of defense converted it to oh number seven derek white finds tatum wing jumper misses
# After Flow:--------------->in the paint anticipates the pass whole lot of defense converted it to zero number seven derek white finds tatum wing jumper misses
# *Improved*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0435
#
# start 5 from 24
# flow_output_norm: Van Cornet cleans up the offensive glass. Put-back jam over by Caro.
# index: 5, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->and kornet cleans up the offensive glass put back jam over by chero
# STT raw:------------------>van cornet cleans up the offensive glass put back jam over by caro
# After Flow:--------------->van cornet cleans up the offensive glass put back jam over by caro
# *Same Result*, WER before LLM correction: 0.2308, WER after LLM correction: 0.2308
#
# Best Names: ['Van Cornet']
# sentence build: "Van Cornet explored the topic with keen interest."
# flow_output_norm: "Van Cornet explored the topic with keen interest."
# index: 5, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->and kornet cleans up the offensive glass put back jam over by chero
# STT raw:------------------>van cornet cleans up the offensive glass put back jam over by caro
# After Flow:--------------->van cornet cleans up the offensive glass put back jam over by caro
# *Same Result*, WER before LLM correction: 0.2308, WER after LLM correction: 0.2308
#
# flow_output_norm: [Paolo Banchero]
# index: 5, Pipeline: GenerateNamesPipeline
# Target:------------------->and kornet cleans up the offensive glass put back jam over by chero
# STT raw:------------------>van cornet cleans up the offensive glass put back jam over by caro
# After Flow:--------------->man cornet cleans up the offensive glass put back jam over by caro
# *Same Result*, WER before LLM correction: 0.2308, WER after LLM correction: 0.2308
#
# flow_output_norm: Basketball Play-by-Play
# index: 5, Pipeline: GenerateTopicPipeline
# Target:------------------->and kornet cleans up the offensive glass put back jam over by chero
# STT raw:------------------>van cornet cleans up the offensive glass put back jam over by caro
# After Flow:--------------->man cornette cleans up the offensive glass put back jam over by caro
# *Same Result*, WER before LLM correction: 0.2308, WER after LLM correction: 0.2308
#
# start 6 from 24
# flow_output_norm: Let's get back to Milwaukee. Dame trying to set off the fast break. Pass gets picked off. Siakam sees the lane.
# index: 6, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# STT raw:------------------>let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# After Flow:--------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Best Names: ['Dame Lillard', 'Pascal Siakam']
# sentence build: "Dame Lillard and Pascal Siakam showcased their skills in an intense basketball showdown."
# flow_output_norm: "Dame Lillard and Pascal Siakam showcased their skills in an intense basketball showdown."
# index: 6, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# STT raw:------------------>let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# After Flow:--------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Giannis Antetokounmpo, Pascal Siakam]
# index: 6, Pipeline: GenerateNamesPipeline
# Target:------------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# STT raw:------------------>let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# After Flow:--------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball game commentary
# index: 6, Pipeline: GenerateTopicPipeline
# Target:------------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# STT raw:------------------>let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# After Flow:--------------->let s get back to milwaukee dame trying to set off the fast break pass gets picked off siakam sees the lane
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 7 from 24
# flow_output_norm: Day says, no, no, it's Tom, it's Tom, it's Dave Tom, on a block type of Tommy.
# index: 7, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->dame says nada it s time it s time it s dame time on a block tight for timing
# STT raw:------------------>day says nah nah it s tom it s tom it s dave tom on a block type of tommy
# After Flow:--------------->day says no no it s tom it s tom it s dave tom on a block type of tommy
# *Same Result*, WER before LLM correction: 0.5263, WER after LLM correction: 0.5263
#
# Best Names: ['Tom', 'Dave']
# sentence build: "Tom and Dave discussed strategies for the unknown topic."
# flow_output_norm: "Tom and Dave discussed strategies for the unknown topic."
# index: 7, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->dame says nada it s time it s time it s dame time on a block tight for timing
# STT raw:------------------>day says nah nah it s tom it s tom it s dave tom on a block type of tommy
# After Flow:--------------->dave says nannah it s tom it s tom it s dave dom on a block type of tommy
# *Improved*, WER before LLM correction: 0.5263, WER after LLM correction: 0.4737
#
# flow_output_norm: [Dave Thomas]
# index: 7, Pipeline: GenerateNamesPipeline
# Target:------------------->dame says nada it s time it s time it s dame time on a block tight for timing
# STT raw:------------------>day says nah nah it s tom it s tom it s dave tom on a block type of tommy
# After Flow:--------------->dave says nah nah it s tom it s tom it s dave tom on a block type of tommy
# *Same Result*, WER before LLM correction: 0.5263, WER after LLM correction: 0.5263
#
# flow_output_norm: Interpersonal Communication
# index: 7, Pipeline: GenerateTopicPipeline
# Target:------------------->dame says nada it s time it s time it s dame time on a block tight for timing
# STT raw:------------------>day says nah nah it s tom it s tom it s dave tom on a block type of tommy
# After Flow:--------------->day says nana it s tom it s tom it s dave dom on a block type of tommy
# *Improved*, WER before LLM correction: 0.5263, WER after LLM correction: 0.4737
#
# start 8 from 24
# flow_output_norm: That's how you say my bad when you turn it over. Number five, T. Wolves trying to play bully ball, Randall no.
# index: 8, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->and that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# STT raw:------------------>that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# After Flow:--------------->that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# *Same Result*, WER before LLM correction: 0.0417, WER after LLM correction: 0.0417
#
# Best Names: ['Julius Randle']
# sentence build: Julius Randle impressed everyone with his performance on the court today.
# GenerateWhisperPromptPipeline is corrupted
# flow_output_norm: Julius Randle impressed everyone with his performance on the court today.
# index: 8, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->and that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# STT raw:------------------>that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# After Flow:--------------->and that s how you say my bad when you turn it over
# *Not Improved*, WER before LLM correction: 0.0417, WER after LLM correction: 0.4583
#
# flow_output_norm: [Julius Randle]
# index: 8, Pipeline: GenerateNamesPipeline
# Target:------------------->and that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# STT raw:------------------>that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# After Flow:--------------->that s how you say my bad when you turn it over number five t wolves trying to play bully ball randle no
# *Not Improved*, WER before LLM correction: 0.0417, WER after LLM correction: 0.0833
#
# flow_output_norm: Basketball commentary
# index: 8, Pipeline: GenerateTopicPipeline
# Target:------------------->and that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# STT raw:------------------>that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# After Flow:--------------->that s how you say my bad when you turn it over number five t wolves trying to play bully ball randall no
# *Same Result*, WER before LLM correction: 0.0417, WER after LLM correction: 0.0417
#
# start 9 from 24
# flow_output_norm: AdWords, no! Block by James. LeBron setting off the fast break.
# index: 9, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->edwards no blocked by james lebron setting off the fast break
# STT raw:------------------>adwords no block by james lebron setting off the fast break
# After Flow:--------------->adwords no block by james lebron setting off the fast break
# *Same Result*, WER before LLM correction: 0.1818, WER after LLM correction: 0.1818
#
# Best Names: ['LeBron James']
# sentence build: LeBron James demonstrated extraordinary resilience on the court.
# flow_output_norm: LeBron James demonstrated extraordinary resilience on the court.
# index: 9, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->edwards no blocked by james lebron setting off the fast break
# STT raw:------------------>adwords no block by james lebron setting off the fast break
# After Flow:--------------->adwords no blocked by james lebron setting off the fast break
# *Improved*, WER before LLM correction: 0.1818, WER after LLM correction: 0.0909
#
# flow_output_norm: LeBron James
# index: 9, Pipeline: GenerateNamesPipeline
# Target:------------------->edwards no blocked by james lebron setting off the fast break
# STT raw:------------------>adwords no block by james lebron setting off the fast break
# After Flow:--------------->adwords no blocked by james lebron setting off the fast break
# *Improved*, WER before LLM correction: 0.1818, WER after LLM correction: 0.0909
#
# flow_output_norm: Basketball Commentary
# index: 9, Pipeline: GenerateTopicPipeline
# Target:------------------->edwards no blocked by james lebron setting off the fast break
# STT raw:------------------>adwords no block by james lebron setting off the fast break
# After Flow:--------------->adwords no blocked by james lebron setting off the fast break
# *Improved*, WER before LLM correction: 0.1818, WER after LLM correction: 0.0909
#
# start 10 from 24
# flow_output_norm: Pull up three, knocks it down. Turn the defense into offense. Denying the Ant-Man on the other side and takes it back down.
# index: 10, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->pull up three knocks it down turning defense into offense denying the ant man on the other side and takes it back down
# STT raw:------------------>pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# After Flow:--------------->pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# *Same Result*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0870
#
# Best Names: ['Anthony Edwards']
# sentence build: Anthony Edwards showcased his skills, captivating the audience with his performance.
# flow_output_norm: Anthony Edwards showcased his skills, captivating the audience with his performance.
# index: 10, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->pull up three knocks it down turning defense into offense denying the ant man on the other side and takes it back down
# STT raw:------------------>pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# After Flow:--------------->pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# *Same Result*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0870
#
# flow_output_norm: [Anthony Edwards]
# index: 10, Pipeline: GenerateNamesPipeline
# Target:------------------->pull up three knocks it down turning defense into offense denying the ant man on the other side and takes it back down
# STT raw:------------------>pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# After Flow:--------------->pull up three knocks it down turning defense into offense denying the ant man on the other side and takes it back down
# *Improved*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball commentary
# index: 10, Pipeline: GenerateTopicPipeline
# Target:------------------->pull up three knocks it down turning defense into offense denying the ant man on the other side and takes it back down
# STT raw:------------------>pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# After Flow:--------------->pull up three knocks it down turn the defense into offense denying the ant man on the other side and takes it back down
# *Same Result*, WER before LLM correction: 0.0870, WER after LLM correction: 0.0870
#
# start 11 from 24
# flow_output_norm: Dustin off them video games. James highlights. Let's go, Ron. Back to Milwaukee we go. We told you we had some defense for y'all tonight.
# index: 11, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->dusting off them video games james highlights let s go bron back to milwaukee we go we told you we had some defense for y all tonight
# STT raw:------------------>dustin off them video games james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# After Flow:--------------->dustin off them video games james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# *Same Result*, WER before LLM correction: 0.0741, WER after LLM correction: 0.0741
#
# Best Names: ['James']
# sentence build: James attended the conference to discuss new advancements.
# flow_output_norm: James attended the conference to discuss new advancements.
# index: 11, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->dusting off them video games james highlights let s go bron back to milwaukee we go we told you we had some defense for y all tonight
# STT raw:------------------>dustin off them video games james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# After Flow:--------------->dustin northam video game james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# *Not Improved*, WER before LLM correction: 0.0741, WER after LLM correction: 0.1852
#
# flow_output_norm: [LeBron James]
# index: 11, Pipeline: GenerateNamesPipeline
# Target:------------------->dusting off them video games james highlights let s go bron back to milwaukee we go we told you we had some defense for y all tonight
# STT raw:------------------>dustin off them video games james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# After Flow:--------------->dustin northam video game james highlights let s go bron back to milwaukee we go we told you we had some defense for y all tonight
# *Not Improved*, WER before LLM correction: 0.0741, WER after LLM correction: 0.1481
#
# flow_output_norm: Video Game Commentary
# index: 11, Pipeline: GenerateTopicPipeline
# Target:------------------->dusting off them video games james highlights let s go bron back to milwaukee we go we told you we had some defense for y all tonight
# STT raw:------------------>dustin off them video games james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# After Flow:--------------->dustin northam video game james highlights let s go ron back to milwaukee we go we told you we had some defense for y all tonight
# *Not Improved*, WER before LLM correction: 0.0741, WER after LLM correction: 0.1852
#
# start 12 from 24
# flow_output_norm: Giannis breaks up the pass. We're going on the fast break. Tough layup and one.
# index: 12, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->giannis breaks up the pass we going on the fast break tough layup and one
# STT raw:------------------>giannis breaks up the pass we going on the fast break tough layup and one
# After Flow:--------------->giannis breaks up the pass we re going on the fast break tough layup and one
# *Not Improved*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0667
#
# Best Names: ['Giannis Antetokounmpo']
# sentence build: "Giannis Antetokounmpo dominated the court with his incredible skills."
# flow_output_norm: "Giannis Antetokounmpo dominated the court with his incredible skills."
# index: 12, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->giannis breaks up the pass we going on the fast break tough layup and one
# STT raw:------------------>giannis breaks up the pass we going on the fast break tough layup and one
# After Flow:--------------->giannis breaks up the pass we going on the fast break tough layup and one
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Giannis Antetokounmpo]
# index: 12, Pipeline: GenerateNamesPipeline
# Target:------------------->giannis breaks up the pass we going on the fast break tough layup and one
# STT raw:------------------>giannis breaks up the pass we going on the fast break tough layup and one
# After Flow:--------------->giannis breaks up the pass we going on the fast break tough layup and one
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball play-by-play
# index: 12, Pipeline: GenerateTopicPipeline
# Target:------------------->giannis breaks up the pass we going on the fast break tough layup and one
# STT raw:------------------>giannis breaks up the pass we going on the fast break tough layup and one
# After Flow:--------------->giannis breaks up the pass we going on the fast break tough layup and one
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 13 from 24
# flow_output_norm: Giannis rising up, altering the shot, and then cashes it in.
# index: 13, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->giannis raising up altering the shot and then cashes it in
# STT raw:------------------>giannis raising up altering the shot and then cashes it in
# After Flow:--------------->giannis rising up altering the shot and then cashes it in
# *Not Improved*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0909
#
# Best Names: ['Giannis Antetokounmpo']
# sentence build: "Giannis Antetokounmpo demonstrated remarkable skill on the basketball court with his signature moves."
# flow_output_norm: "Giannis Antetokounmpo demonstrated remarkable skill on the basketball court with his signature moves."
# index: 13, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->giannis raising up altering the shot and then cashes it in
# STT raw:------------------>giannis raising up altering the shot and then cashes it in
# After Flow:--------------->giannis raising up altering the shot and then cashes it in
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Giannis Antetokounmpo]
# index: 13, Pipeline: GenerateNamesPipeline
# Target:------------------->giannis raising up altering the shot and then cashes it in
# STT raw:------------------>giannis raising up altering the shot and then cashes it in
# After Flow:--------------->giannis raising up altering the shot and then cashes it in
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball Game Commentary
# index: 13, Pipeline: GenerateTopicPipeline
# Target:------------------->giannis raising up altering the shot and then cashes it in
# STT raw:------------------>giannis raising up altering the shot and then cashes it in
# After Flow:--------------->giannis raising up altering the shot and then cashes it in
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 14 from 24
# flow_output_norm: As only the Greek Freak can do. Act number four, you see a little dance at the end. Number three.
# index: 14, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->as only the greek freak can do at number four you see a little dance at the end number three
# STT raw:------------------>as only the greek freak can do act number four you see a little dance at the end number three
# After Flow:--------------->as only the greek freak can do act number four you see a little dance at the end number three
# *Same Result*, WER before LLM correction: 0.0500, WER after LLM correction: 0.0500
#
# Best Names: ['Giannis Antetokounmpo']
# sentence build: "Giannis Antetokounmpo dominates the court with his incredible athletic prowess."
# GenerateWhisperPromptPipeline is corrupted
# flow_output_norm: "Giannis Antetokounmpo dominates the court with his incredible athletic prowess."
# index: 14, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->as only the greek freak can do at number four you see a little dance at the end number three
# STT raw:------------------>as only the greek freak can do act number four you see a little dance at the end number three
# After Flow:--------------->that s only the greek freak can do
# *Not Improved*, WER before LLM correction: 0.0500, WER after LLM correction: 0.7500
#
# GenerateNamesPipeline is corrupted
# flow_output_norm: [Giannis Antetokounmpo]
# index: 14, Pipeline: GenerateNamesPipeline
# Target:------------------->as only the greek freak can do at number four you see a little dance at the end number three
# STT raw:------------------>as only the greek freak can do act number four you see a little dance at the end number three
# After Flow:--------------->as only the greek freak can do act number four you see a little dance at the end number three roll the dice
# *Not Improved*, WER before LLM correction: 0.0500, WER after LLM correction: 0.2000
#
# GenerateTopicPipeline is corrupted
# flow_output_norm: Sports commentary
# index: 14, Pipeline: GenerateTopicPipeline
# Target:------------------->as only the greek freak can do at number four you see a little dance at the end number three
# STT raw:------------------>as only the greek freak can do act number four you see a little dance at the end number three
# After Flow:--------------->as only the greek freak can do
# *Not Improved*, WER before LLM correction: 0.0500, WER after LLM correction: 0.6500
#
# start 15 from 24
# flow_output_norm: Randall, DiVincenzo, oh, the step back knocks down the corner pocket.
# index: 15, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->randall divincenzo the step back knocks down the quarter pocket
# STT raw:------------------>randall divincenzo oh the step back knocks down the quarter pocket
# After Flow:--------------->randall divincenzo oh the step back knocks down the corner pocket
# *Not Improved*, WER before LLM correction: 0.1000, WER after LLM correction: 0.2000
#
# Best Names: ['Julius Randle', 'Donte DiVincenzo']
# sentence build: "Julius Randle and Donte DiVincenzo showcase their skills on the court."
# flow_output_norm: "Julius Randle and Donte DiVincenzo showcase their skills on the court."
# index: 15, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->randall divincenzo the step back knocks down the quarter pocket
# STT raw:------------------>randall divincenzo oh the step back knocks down the quarter pocket
# After Flow:--------------->randle divincenzo oh the step back knocks down the quarter pocket
# *Not Improved*, WER before LLM correction: 0.1000, WER after LLM correction: 0.2000
#
# flow_output_norm: [Dante DiVincenzo]
# index: 15, Pipeline: GenerateNamesPipeline
# Target:------------------->randall divincenzo the step back knocks down the quarter pocket
# STT raw:------------------>randall divincenzo oh the step back knocks down the quarter pocket
# After Flow:--------------->randall divincenzo oh the step back knocks down the quarter pocket
# *Same Result*, WER before LLM correction: 0.1000, WER after LLM correction: 0.1000
#
# flow_output_norm: Basketball Commentary
# index: 15, Pipeline: GenerateTopicPipeline
# Target:------------------->randall divincenzo the step back knocks down the quarter pocket
# STT raw:------------------>randall divincenzo oh the step back knocks down the quarter pocket
# After Flow:--------------->randall divincenzo oh the step back knocks down the quarter pocket
# *Same Result*, WER before LLM correction: 0.1000, WER after LLM correction: 0.1000
#
# start 16 from 24
# flow_output_norm: Got it. Diaz touching Earth was looking like he was planting some seeds there. Number two.
# index: 16, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->got it dfs touching earth was looking like he was planting some seeds there number two
# STT raw:------------------>got it dfs touching earth was looking like he was planting some seeds there number two
# After Flow:--------------->got it diaz touching earth was looking like he was planting some seeds there number two
# *Not Improved*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0625
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 16, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->got it dfs touching earth was looking like he was planting some seeds there number two
# STT raw:------------------>got it dfs touching earth was looking like he was planting some seeds there number two
# After Flow:--------------->got it dfs touching earth was looking like he was planting some seeds there number two
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: []
# index: 16, Pipeline: GenerateNamesPipeline
# Target:------------------->got it dfs touching earth was looking like he was planting some seeds there number two
# STT raw:------------------>got it dfs touching earth was looking like he was planting some seeds there number two
# After Flow:--------------->got it dfs touching earth was looking like he was planting some seeds there number two
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Space or Science Fiction
# index: 16, Pipeline: GenerateTopicPipeline
# Target:------------------->got it dfs touching earth was looking like he was planting some seeds there number two
# STT raw:------------------>got it dfs touching earth was looking like he was planting some seeds there number two
# After Flow:--------------->got it dfs touching earth was looking like he was planting some seeds there number two
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 17 from 24
# flow_output_norm: Finney-Smith in the paint, blocked by Gobert, catches it out of the air. Then on the drive.
# index: 17, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# STT raw:------------------>finney smith in the paint blocked by gobert catches it out of the air then on the drive
# After Flow:--------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Best Names: ['Finney Smith', 'Rudy Gobert']
# sentence build: "Finney Smith collaborated with Rudy Gobert in a dazzling display on the court."
# flow_output_norm: "Finney Smith collaborated with Rudy Gobert in a dazzling display on the court."
# index: 17, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# STT raw:------------------>finney smith in the paint blocked by gobert catches it out of the air then on the drive
# After Flow:--------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Finney-Smith, Rudy Gobert]
# index: 17, Pipeline: GenerateNamesPipeline
# Target:------------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# STT raw:------------------>finney smith in the paint blocked by gobert catches it out of the air then on the drive
# After Flow:--------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball play-by-play
# index: 17, Pipeline: GenerateTopicPipeline
# Target:------------------->finney smith in the paint blocked by gobert catches it out of the air then on the drive
# STT raw:------------------>finney smith in the paint blocked by gobert catches it out of the air then on the drive
# After Flow:--------------->fifty smith in the paint block by go bad catches it out of the air then on the drive
# *Not Improved*, WER before LLM correction: 0.0000, WER after LLM correction: 0.2222
#
# start 18 from 24
# flow_output_norm: Ant-Man two-handed jam, getting electric in the first. Rudy Gobert playing Big Brother ball.
# index: 18, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# STT raw:------------------>ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# After Flow:--------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Best Names: ['Anthony Edwards', 'Rudy Gobert']
# sentence build: "Anthony Edwards and Rudy Gobert led their team to victory."
# flow_output_norm: "Anthony Edwards and Rudy Gobert led their team to victory."
# index: 18, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# STT raw:------------------>ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# After Flow:--------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Anthony Edwards, Rudy Gobert]
# index: 18, Pipeline: GenerateNamesPipeline
# Target:------------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# STT raw:------------------>ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# After Flow:--------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball commentary
# index: 18, Pipeline: GenerateTopicPipeline
# Target:------------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# STT raw:------------------>ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# After Flow:--------------->ant man two handed jam getting electric in the first rudy gobert playing big brother ball
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 19 from 24
# flow_output_norm: transcript: Snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# index: 19, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->snatches it out of the sky and then ant makes it look nice on the other side and at the number one spot
# STT raw:------------------>snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# After Flow:--------------->transcript snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# *Not Improved*, WER before LLM correction: 0.0435, WER after LLM correction: 0.0870
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 19, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->snatches it out of the sky and then ant makes it look nice on the other side and at the number one spot
# STT raw:------------------>snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# After Flow:--------------->snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# *Same Result*, WER before LLM correction: 0.0435, WER after LLM correction: 0.0435
#
# GenerateNamesPipeline is corrupted
# flow_output_norm: []
# index: 19, Pipeline: GenerateNamesPipeline
# Target:------------------->snatches it out of the sky and then ant makes it look nice on the other side and at the number one spot
# STT raw:------------------>snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# After Flow:--------------->the other side and at the number one spot
# *Not Improved*, WER before LLM correction: 0.0435, WER after LLM correction: 0.6087
#
# flow_output_norm: American Football Draft
# index: 19, Pipeline: GenerateTopicPipeline
# Target:------------------->snatches it out of the sky and then ant makes it look nice on the other side and at the number one spot
# STT raw:------------------>snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# After Flow:--------------->snatches it out of the sky and the ant makes it look nice on the other side and at the number one spot
# *Same Result*, WER before LLM correction: 0.0435, WER after LLM correction: 0.0435
#
# start 20 from 24
# flow_output_norm: Luca grabs the board and the flex. There goes baseline. Ross is up!
# index: 20, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->luka grabs the board ant deflects there goes baseline rises up
# STT raw:------------------>luca grabs the board and the flex there goes baseline ross is up
# After Flow:--------------->luca grabs the board and the flex there goes baseline ross is up
# *Same Result*, WER before LLM correction: 0.5455, WER after LLM correction: 0.5455
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 20, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->luka grabs the board ant deflects there goes baseline rises up
# STT raw:------------------>luca grabs the board and the flex there goes baseline ross is up
# After Flow:--------------->luca grabs the board and the flex there goes baseline ross is up
# *Same Result*, WER before LLM correction: 0.5455, WER after LLM correction: 0.5455
#
# flow_output_norm: []
# index: 20, Pipeline: GenerateNamesPipeline
# Target:------------------->luka grabs the board ant deflects there goes baseline rises up
# STT raw:------------------>luca grabs the board and the flex there goes baseline ross is up
# After Flow:--------------->luca grabs the board and the flex there goes baseline rushes up
# *Improved*, WER before LLM correction: 0.5455, WER after LLM correction: 0.4545
#
# flow_output_norm: Snowboarding
# index: 20, Pipeline: GenerateTopicPipeline
# Target:------------------->luka grabs the board ant deflects there goes baseline rises up
# STT raw:------------------>luca grabs the board and the flex there goes baseline ross is up
# After Flow:--------------->luca grabs the board and the flex there goes baseline rushes up
# *Improved*, WER before LLM correction: 0.5455, WER after LLM correction: 0.4545
#
# start 21 from 24
# flow_output_norm: baseline jam sending Luka Dončić to the Quantum Realm
# index: 21, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->baseline jam sending luka doncic to the quantum realm
# STT raw:------------------>baseline jam sending luca doncic to the quantum realm
# After Flow:--------------->baseline jam sending luka don i to the quantum realm
# *Not Improved*, WER before LLM correction: 0.1111, WER after LLM correction: 0.2222
#
# Best Names: ['Luka Dončić']
# sentence build: Luka Dončić showcased his skills in a thrilling game last night.
# flow_output_norm: Luka Dončić showcased his skills in a thrilling game last night.
# index: 21, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->baseline jam sending luka doncic to the quantum realm
# STT raw:------------------>baseline jam sending luca doncic to the quantum realm
# After Flow:--------------->baseline jam sending luka doncic to the quantum realm
# *Improved*, WER before LLM correction: 0.1111, WER after LLM correction: 0.0000
#
# flow_output_norm: [Luka Doncic]
# index: 21, Pipeline: GenerateNamesPipeline
# Target:------------------->baseline jam sending luka doncic to the quantum realm
# STT raw:------------------>baseline jam sending luca doncic to the quantum realm
# After Flow:--------------->baseline jam sending luka doncic to the quantum realm
# *Improved*, WER before LLM correction: 0.1111, WER after LLM correction: 0.0000
#
# flow_output_norm: Basketball and Pop Culture
# index: 21, Pipeline: GenerateTopicPipeline
# Target:------------------->baseline jam sending luka doncic to the quantum realm
# STT raw:------------------>baseline jam sending luca doncic to the quantum realm
# After Flow:--------------->baseline jam sending luka doncic to the quantum realm
# *Improved*, WER before LLM correction: 0.1111, WER after LLM correction: 0.0000
#
# start 22 from 24
# flow_output_norm: Ant won't be denied. Minnesota wins. And Ant-Man gets the number one spot on the top 10.
# index: 22, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# STT raw:------------------>ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# After Flow:--------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 22, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# STT raw:------------------>ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# After Flow:--------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: [Anthony Edwards]
# index: 22, Pipeline: GenerateNamesPipeline
# Target:------------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# STT raw:------------------>ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# After Flow:--------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Topic: Basketball/Sports Highlights
# index: 22, Pipeline: GenerateTopicPipeline
# Target:------------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# STT raw:------------------>ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# After Flow:--------------->ant won t be denied minnesota wins and ant man gets the number one spot on the top ten
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# start 23 from 24
# flow_output_norm: I'm Geoff Johnson. We'll talk to you soon.
# index: 23, Pipeline: FixTranscriptByLLMPipeline
# Target:------------------->i m geoff johnson we ll talk to you soon
# STT raw:------------------>i m geoff johnson we ll talk to you soon
# After Flow:--------------->i m geoff johnson we ll talk to you soon
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Best Names: []
# sentence build:
# Pipeline GenerateWhisperPromptPipeline returned an empty response.
# flow_output_norm:
# index: 23, Pipeline: GenerateWhisperPromptPipeline
# Target:------------------->i m geoff johnson we ll talk to you soon
# STT raw:------------------>i m geoff johnson we ll talk to you soon
# After Flow:--------------->i m geoff johnson we ll talk to you soon
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Geoff Johnson
# index: 23, Pipeline: GenerateNamesPipeline
# Target:------------------->i m geoff johnson we ll talk to you soon
# STT raw:------------------>i m geoff johnson we ll talk to you soon
# After Flow:--------------->i m geoff johnson we ll talk to you soon
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# flow_output_norm: Output:
# End of communication
# index: 23, Pipeline: GenerateTopicPipeline
# Target:------------------->i m geoff johnson we ll talk to you soon
# STT raw:------------------>i m geoff johnson we ll talk to you soon
# After Flow:--------------->i m geoff johnson we ll talk to you soon
# *Same Result*, WER before LLM correction: 0.0000, WER after LLM correction: 0.0000
#
# Results saved to full_report_fs8ryPzUgW0_1.8.25

# %%
file_eval_paths = [
    "full_report_-71SWHoWQJI_31.1.7.25.csv",
    "full_report_-hL_qIOiQAc_31.7.25.csv",
    "full_report_8IVObmY-QTg_31.1.7.25.csv",
    "full_report_df-0dAkQImY_31.1.7.25.csv",
    "full_report_n1e18JbhUXs_31.1.7.25.csv",
    "full_report_Tt8Cepx7HqY_31.1.7.25.csv",
    "full_report_xwJwMgEkcs4_31.1.7.25.csv",
    "full_report_pFfteuNJenw_31.1.7.25.csv",
    # "full_report_xwJwMgEkcs4_1.8.25.csv", # Not good results, not used in the evaluation
    "full_report_8IVObmY-QTg_1.8.25.csv", 
]

# %%
file_eval_path = file_eval_paths[0]

df = pd.read_csv(file_eval_path)  # adjust path if needed

# Identify WER columns
wer_cols = [c for c in df.columns if c.endswith("_wer")]

# Compute improvement percentages vs stt_raw_wer
improvement_df = pd.DataFrame()
for col in wer_cols:
    if col == "stt_raw_wer":
        continue
    improvement_df[col] = (df["stt_raw_wer"] - df[col]) / df["stt_raw_wer"] * 100

# Summary stats
summary = pd.DataFrame({
    "mean_wer": {col: df[col].mean() for col in wer_cols},
    "median_wer": {col: df[col].median() for col in wer_cols},
    "mean_improvement_%": {col: improvement_df[col].mean() if col in improvement_df else np.nan for col in wer_cols},
    "median_improvement_%": {col: improvement_df[col].median() if col in improvement_df else np.nan for col in wer_cols},
})

print("=== Summary ===")
print(summary)
# Out:
# === Summary ===
#                                    mean_wer  median_wer  mean_improvement_%  \
# stt_raw_wer                        0.121777    0.082553                 NaN
# FixTranscriptByLLMPipeline_wer     0.117443    0.078947                -inf
# GenerateWhisperPromptPipeline_wer  0.159563    0.084524                -inf
# GenerateNamesPipeline_wer          0.092798    0.075236                -inf
# GenerateTopicPipeline_wer          0.146418    0.084040                -inf
#
#                                    median_improvement_%
# stt_raw_wer                                         NaN
# FixTranscriptByLLMPipeline_wer                      0.0
# GenerateWhisperPromptPipeline_wer                   0.0
# GenerateNamesPipeline_wer                           0.0
# GenerateTopicPipeline_wer                           0.0

# %%
from typing import List
import numpy as np
import pandas as pd
from collections import defaultdict

def evaluate_wer_pipeline(
    file_eval_paths: List[str],
    header_columns: int = 1,
    aggregate: bool = True,              # <— new: also print an "all files" rollup
    print_per_file: bool = True,         # <— keep per-file printouts (set False to suppress)
    tol: float = 1e-8                    # <— tolerance for "Same" (np.isclose)
) -> None:
    """
    Evaluate WER improvements across multiple pipeline reports.

    Args:
        file_eval_paths: List of CSV paths, each with 'stt_raw_wer' and one or more '*_wer' columns.
        header_columns:  Passed through to your load_csv.
        aggregate:       If True, also show a single summary accumulated over all files.
        print_per_file:  If True, print each file's summary as before.
        tol:             Absolute tolerance for treating WER as "Same".
    """
    # Global accumulator keyed by pipeline name
    agg = defaultdict(lambda: {"total_segments": 0, "Improved": 0, "Same": 0, "Not Improved": 0})

    for file_eval_path in file_eval_paths:
        if print_per_file:
            print(f"\nProcessing file: {file_eval_path}")

        df = load_csv(file_eval_path, header_columns)

        # Identify WER pipelines excluding the raw baseline
        wer_cols = [c for c in df.columns if c.endswith("_wer")]
        if "stt_raw_wer" not in wer_cols:
            # Skip files that don't have the baseline column
            if print_per_file:
                print("  Skipped: missing 'stt_raw_wer'")
            continue

        other_pipelines = [c for c in wer_cols if c != "stt_raw_wer"]

        summary_rows = []
        raw = df["stt_raw_wer"]

        for col in other_pipelines:
            other = df[col]

            # masks: improved/same/not improved (treat NaNs as not comparable)
            valid_mask = (~raw.isna()) & (~other.isna())
            improved_mask = (other < raw) & valid_mask
            same_mask = np.isclose(other, raw, atol=tol, rtol=0, equal_nan=False) & valid_mask
            not_improved_mask = (other > raw) & valid_mask

            improved_count = int(improved_mask.sum())
            same_count = int(same_mask.sum())
            not_improved_count = int(not_improved_mask.sum())
            total_segments = int(valid_mask.sum())  # only count rows where both WERs exist

            # Per-file summary row
            summary_rows.append({
                "pipeline": col,
                "total_segments": total_segments,
                "Improved": improved_count,
                "Same": same_count,
                "Not Improved": not_improved_count,
                "Improved_%": (improved_count / total_segments * 100) if total_segments else 0.0,
                "Same_%": (same_count / total_segments * 100) if total_segments else 0.0,
                "Not_Improved_%": (not_improved_count / total_segments * 100) if total_segments else 0.0,
            })

            # Accumulate into global rollup
            agg[col]["total_segments"] += total_segments
            agg[col]["Improved"] += improved_count
            agg[col]["Same"] += same_count
            agg[col]["Not Improved"] += not_improved_count

        if print_per_file:
            summary_df = pd.DataFrame(summary_rows)
            if not summary_df.empty:
                print(summary_df.to_string(index=False))
            else:
                print("  No pipeline columns found to compare.")

    # Print a single accumulated summary across all files
    if aggregate and agg:
        rows = []
        for pipeline, counts in agg.items():
            total = counts["total_segments"]
            imp = counts["Improved"]
            same = counts["Same"]
            not_imp = counts["Not Improved"]
            rows.append({
                "pipeline": pipeline,
                "total_segments": total,
                "Improved": imp,
                "Same": same,
                "Not Improved": not_imp,
                "Improved_%": (imp / total * 100) if total else 0.0,
                "Same_%": (same / total * 100) if total else 0.0,
                "Not_Improved_%": (not_imp / total * 100) if total else 0.0,
            })

        agg_df = pd.DataFrame(rows).sort_values(["Improved_%", "Improved"], ascending=[False, False])
        print("\n=== Accumulated summary across ALL files ===")
        print(agg_df.to_string(index=False))

# %% [markdown]
# ### Make adjusments:

# %%
# Put all the csv files from the after_evaluation folder in file_eval_paths
file_eval_paths = os.listdir("after_evaluation")
file_eval_paths = [f"after_evaluation/{f}" for f in file_eval_paths if f.endswith(".csv")]

evaluate_wer_pipeline(file_eval_paths, 1)
#evaluate_wer_pipeline(["after_evaluation/full_report_fs8ryPzUgW0_2.8.25.csv"])
#evaluate_wer_pipeline(file_eval_paths)
# Out:
# Processing file: after_evaluation/full_report_8IVObmY-QTg_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              76        10    53            13   13.157895 69.736842       17.105263
# GenerateWhisperPromptPipeline_wer              76        22    51             3   28.947368 67.105263        3.947368
#         GenerateNamesPipeline_wer              76        20    34            22   26.315789 44.736842       28.947368
#         GenerateTopicPipeline_wer              76        18    30            28   23.684211 39.473684       36.842105
#
# Processing file: after_evaluation/full_report_xwJwMgEkcs4_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%  Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              40         7    27             6        17.5    67.5            15.0
# GenerateWhisperPromptPipeline_wer              40         9    30             1        22.5    75.0             2.5
#         GenerateNamesPipeline_wer              40         8    16            16        20.0    40.0            40.0
#         GenerateTopicPipeline_wer              40         9     9            22        22.5    22.5            55.0
#
# Processing file: after_evaluation/full_report_Tt8Cepx7HqY_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%  Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              32         7    17             8      21.875  53.125          25.000
# GenerateWhisperPromptPipeline_wer              32        16    14             2      50.000  43.750           6.250
#         GenerateNamesPipeline_wer              32         9    18             5      28.125  56.250          15.625
#         GenerateTopicPipeline_wer              32         7    20             5      21.875  62.500          15.625
#
# Processing file: after_evaluation/full_report_fs8ryPzUgW0_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              24         2    14             8    8.333333 58.333333       33.333333
# GenerateWhisperPromptPipeline_wer              24         4    20             0   16.666667 83.333333        0.000000
#         GenerateNamesPipeline_wer              24         6    15             3   25.000000 62.500000       12.500000
#         GenerateTopicPipeline_wer              24         6    15             3   25.000000 62.500000       12.500000
#
# Processing file: after_evaluation/full_report_pFfteuNJenw_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              66         1    55            10    1.515152 83.333333       15.151515
# GenerateWhisperPromptPipeline_wer              66        25    40             1   37.878788 60.606061        1.515152
#         GenerateNamesPipeline_wer              66        20    38             8   30.303030 57.575758       12.121212
#         GenerateTopicPipeline_wer              66         7    45            14   10.606061 68.181818       21.212121
#
# Processing file: after_evaluation/full_report_-hL_qIOiQAc_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              41        11    23             7   26.829268 56.097561       17.073171
# GenerateWhisperPromptPipeline_wer              41        21    13             7   51.219512 31.707317       17.073171
#         GenerateNamesPipeline_wer              40        21    12             7   52.500000 30.000000       17.500000
#         GenerateTopicPipeline_wer              38         8    18            12   21.052632 47.368421       31.578947
#
# Processing file: after_evaluation/full_report_n1e18JbhUXs_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              44        12    24             8   27.272727 54.545455       18.181818
# GenerateWhisperPromptPipeline_wer              44        23    18             3   52.272727 40.909091        6.818182
#         GenerateNamesPipeline_wer              44        24    16             4   54.545455 36.363636        9.090909
#         GenerateTopicPipeline_wer              44        12    25             7   27.272727 56.818182       15.909091
#
# Processing file: after_evaluation/full_report_-71SWHoWQJI_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              48        12    25            11   25.000000 52.083333       22.916667
# GenerateWhisperPromptPipeline_wer              48        18    24             6   37.500000 50.000000       12.500000
#         GenerateNamesPipeline_wer              48        19    17            12   39.583333 35.416667       25.000000
#         GenerateTopicPipeline_wer              48        12    25            11   25.000000 52.083333       22.916667
#
# Processing file: after_evaluation/full_report_df-0dAkQImY_2.8.25.csv
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%  Same_%  Not_Improved_%
#    FixTranscriptByLLMPipeline_wer              50        19    20            11        38.0    40.0            22.0
# GenerateWhisperPromptPipeline_wer              50        31    12             7        62.0    24.0            14.0
#         GenerateNamesPipeline_wer              50        28    13             9        56.0    26.0            18.0
#         GenerateTopicPipeline_wer              50         8    37             5        16.0    74.0            10.0
#
# === Accumulated summary across ALL files ===
#                          pipeline  total_segments  Improved  Same  Not Improved  Improved_%    Same_%  Not_Improved_%
# GenerateWhisperPromptPipeline_wer             421       169   222            30   40.142518 52.731591        7.125891
#         GenerateNamesPipeline_wer             420       155   179            86   36.904762 42.619048       20.476190
#         GenerateTopicPipeline_wer             418        87   224           107   20.813397 53.588517       25.598086
#    FixTranscriptByLLMPipeline_wer             421        81   258            82   19.239905 61.282660       19.477435
